# %% [markdown]
# # BV Data Work

# %%
import pandas as pd

# %%
inputs = pd.read_excel(r"C:\Users\AM20161755\Desktop\BV\Milestone 1 - Master Engineering Content_wo Macros.xlsm", 
                       sheet_name="InputOutputFields",
                       header=0)

#change file path

# %%
inputs.head()
# Out:
#                               IOFieldName       ValueType UOMType  \
# 0         Major corridors/UG utility plan            link     NaN
# 1              Prelim Geotechnical Report            link     NaN
# 2                    Final Geotech Report            link     NaN
# 3  Prelim Architectural Building in Model  checkbox (Y/N)     NaN
# 4   Final Architectural Building in Model  checkbox (Y/N)     NaN
#
#   Source of Data                Scope Responsible Discipline  \
# 0            NaN            CWA-Level                   Site
# 1            NaN        Project-Level           Geotechnical
# 2            NaN        Project-Level           Geotechnical
# 3            NaN  Structure Tag-Level          Architectural
# 4            NaN  Structure Tag-Level          Architectural
#
#   FragnetStep Identifier FragnetStep Deliverable FEED (Y) DBPMS File Type  \
# 0               V016.002                     NaN      NaN  2D Deliverable
# ...

# %%
inputs.dtypes
# Out:
# IOFieldName                                                                                                                                                      object
# ValueType                                                                                                                                                        object
# UOMType                                                                                                                                                          object
# Source of Data                                                                                                                                                   object
# Scope                                                                                                                                                            object
# ...
